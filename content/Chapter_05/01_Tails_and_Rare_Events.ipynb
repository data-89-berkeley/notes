# %% [markdown]
# ---
# numbering:
#   title:
#     offset: 1
# ---

# %% [markdown]
# (ch5.1)=
# # Tails and Rare Events
#
# % motivation
#
# % example of a tail (visual)
#
# % relation to rare events, and example rare event setting
#
# % define the survival function
#
# % relate to CDF
#
# % express as a series

# %% [markdown]
# # Examples:
#
# ## Geometric Distribution
#
# % define, recall PMF
#
# % plot PMF
#
# % express CDF and survival as sums of PMF
#
# % solve for survival function by probability rules
#
# % return CDF and survival, and plot
#
# % show that the survival function is exponential in its argument
#
# % generalize to geometric series and prove sum by factoring polynomial

# %% [markdown]
# ## Harmonic Distributions
#
# % define, write down PMF
#
# % applications: Zipf's law, degree distributions
#
# % Harmonic series
#
# % show that the series fails to converge
#
# % need to understand asymptotic rates

# %% [markdown]
# ## Exponential Example
#
# % define, recall PDF
#
# % plot
#
# % make analogy to Geometric
#
# % find survival function by integrating
#
# % show that the survival function is also exponential
#
# % relate to CDF

# %% [markdown]
# ## Pareto Example
#
# % define, recall PDF
#
# % plot
#
# % make analogy to Harmonic
#
# % find survival function by integrating
#
# % show that it fails to converge in Harmonic case
