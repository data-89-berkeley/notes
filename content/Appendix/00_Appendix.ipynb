# %% [markdown]
# ---
# numbering:
#   title:
#     offset: 0
# ---

# %% [markdown]
# (chA.0)=
# # Appendices

# %% [markdown]
# This Appendix will store short helper chapters designed to help with prerequisite material, or with material that is used in the class, but is ancillary to the main aim.
#
# It contains:
#
# 1. A helper chapter on combinatorics [Section A.1](#chA.1)
