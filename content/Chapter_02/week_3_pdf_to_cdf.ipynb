# %%
from utils_dist import run_pdf_cdf_explorer

# %%
# Interactive PDF/PMF  CDF explorer
run_pdf_cdf_explorer()
# Out:
# VBox(children=(VBox(children=(Dropdown(description='Type:', index=1, options=('Discrete', 'Continuous'), style…

# %%
run_pdf_cdf_explorer(dist="Pareto", show="CDF")  # Pareto, CDF only
# Out:
# VBox(children=(VBox(children=(Dropdown(description='Type:', disabled=True, options=('Continuous',), style=Desc…
